# %%
import numpy as np
import matplotlib.pyplot as plt

# for null spaces
import scipy.linalg

# a pretty-looking matrix from scipy
from scipy.linalg import toeplitz

# %%
B = np.random.randn(5,5)
print(B)
print([B[1,:]])
print([B[:,1]])
# Out:
# [[ 0.02319132 -0.53483136 -0.26558041 -0.05747885  0.12226597]
#  [-0.62611179 -0.6551313  -1.97273693  1.21200674 -1.85273749]
#  [-1.05094817  0.62702682  0.30419855 -1.32726058  1.10495764]
#  [-0.11645389  0.05264698 -0.14035394 -3.15873864 -0.43201774]
#  [ 0.31573854 -0.77576138 -0.97266223  0.46169031 -0.30224305]]
# [array([-0.62611179, -0.6551313 , -1.97273693,  1.21200674, -1.85273749])]
# [array([-0.53483136, -0.6551313 ,  0.62702682,  0.05264698, -0.77576138])]

# %%
fig,axs = plt.subplots(1,3,figsize=(10,3))

axs[0].imshow(B,cmap='gray')
axs[1].imshow([B[2,:]],cmap='gray')
axs[2].imshow([B[:,1]],cmap='gray')

for i in range(3): axs[i].axis('off')
plt.tight_layout()
