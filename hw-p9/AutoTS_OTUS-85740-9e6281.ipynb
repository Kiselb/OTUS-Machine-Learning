# %%
! pip install autots
# Out:
# Collecting autots
#   Downloading autots-0.6.14-py3-none-any.whl (843 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 843.3/843.3 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.10/dist-packages (from autots) (1.25.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.10/dist-packages (from autots) (2.0.3)
# Requirement already satisfied: statsmodels>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from autots) (0.14.2)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from autots) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->autots) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->autots) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.0->autots) (2024.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->autots) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->autots) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->autots) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.10.0->autots) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.10.0->autots) (24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.10.0->autots) (1.16.0)
# Installing collected packages: autots
# Successfully installed autots-0.6.14

# %%
# HelloWorld-пример:

from autots.datasets import load_monthly # also: _hourly, _daily, _weekly, or _yearly

df_long = load_monthly(long=True)

# %%
df_long
# Out:
#        datetime      value   series_id  \
# 0    1953-04-01    2.83000        GS10
# 1    1953-05-01    3.05000        GS10
# 2    1953-06-01    3.11000        GS10
# 3    1953-07-01    2.93000        GS10
# 4    1953-08-01    2.95000        GS10
# ...         ...        ...         ...
# 4094 2019-08-01  190.46324  USEPUINDXM
# 4095 2019-09-01  134.36179  USEPUINDXM
# 4096 2019-10-01  118.48822  USEPUINDXM
# 4097 2019-11-01  131.78183  USEPUINDXM
# 4098 2019-12-01  145.03339  USEPUINDXM
#
#                                             series_name
# 0               10-Year Treasury Constant Maturity Rate
# 1               10-Year Treasury Constant Maturity Rate
# 2               10-Year Treasury Constant Maturity Rate
# 3               10-Year Treasury Constant Maturity Rate
# 4               10-Year Treasury Constant Maturity Rate
# ...                                                 ...
# 4094  Economic Policy Uncertainty Index for United S...
# 4095  Economic Policy Uncertainty Index for United S...
# 4096  Economic Policy Uncertainty Index for United S...
# 4097  Economic Policy Uncertainty Index for United S...
# 4098  Economic Policy Uncertainty Index for United S...
#
# [4099 rows x 4 columns]

# %%
model_list = [
    #'LastValueNaive',
    'GLM',
    'ETS',
    'AverageValueNaive',
]

# %%
from autots import AutoTS


model = AutoTS(
    forecast_length=3,
    frequency='infer',
    ensemble='simple',
    max_generations=0,
    num_validations=2,
    model_list=model_list,
)
model = model.fit(df_long, date_col='datetime', value_col='value', id_col='series_id')

# Print the description of the best model
print(model)
# Out:
# Using 1 cpus for n_jobs.
# Data frequency is: MS, used frequency is: MS
# Model Number: 1 with model AverageValueNaive in generation 0 of 0
# Model Number: 2 with model AverageValueNaive in generation 0 of 0
# Model Number: 3 with model AverageValueNaive in generation 0 of 0
# Model Number: 4 with model ETS in generation 0 of 0
# Model Number: 5 with model ETS in generation 0 of 0
# Model Number: 6 with model GLM in generation 0 of 0
# Model Number: 7 with model GLM in generation 0 of 0
# Model Number: 8 with model ETS in generation 0 of 0
# Model Number: 9 with model GLM in generation 0 of 0
# Template Eval Error: ValueError('The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.') in model 9 in generation 0: GLM
# Model Number: 10 with model ETS in generation 0 of 0
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1406: RuntimeWarning: invalid value encountered in log
#   resid_dev -= endog_alpha * np.log(endog_alpha / mu_alpha)
# Model Number: 11 with model AverageValueNaive in generation 0 of 0
# Model Number: 12 with model ETS in generation 0 of 0
# Template Eval Error: Exception("Transformer AlignLastValue failed on inverse from params ffill {'0': {'rows': 1, 'lag': 7, 'method': 'additive', 'strength': 1.0, 'first_value_only': False, 'threshold': 1}, '1': {'lag_1': 12, 'method': 'LastValue'}, '2': {'lag_1': 7, 'method': 'Mean'}, '3': {'rows': 1, 'lag': 1, 'method': 'additive', 'strength': 1.0, 'first_value_only': False, 'threshold': 1}, '4': {'rows': 1, 'lag': 2, 'method': 'additive', 'strength': 0.7, 'first_value_only': True, 'threshold': None}, '5': {'lag': 1, 'fill': 'bfill'}}") in model 12 in generation 0: ETS
# Model Number: 13 with model AverageValueNaive in generation 0 of 0
# Model Number: 14 with model ETS in generation 0 of 0
# Model Number: 15 with model AverageValueNaive in generation 0 of 0
# Model Number: 16 with model GLM in generation 0 of 0
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# /usr/local/lib/python3.10/dist-packages/statsmodels/genmod/families/family.py:1367: ValueWarning: Negative binomial dispersion parameter alpha not set. Using default value alpha=1.0.
#   warnings.warn("Negative binomial dispersion parameter alpha not "
# Model Number: 17 with model AverageValueNaive in generation 0 of 0
# Model Number: 18 with model ETS in generation 0 of 0
# Model Number: 19 with model GLM in generation 0 of 0
# Model Number: 20 with model AverageValueNaive in generation 0 of 0
# Model Number: 21 with model AverageValueNaive in generation 0 of 0
# Model Number: 22 with model AverageValueNaive in generation 0 of 0
# Model Number: 23 with model ETS in generation 0 of 0
# Model Number: 24 with model Ensemble in generation 1 of Ensembles
# Model Number: 25 with model Ensemble in generation 1 of Ensembles
# Model Number: 26 with model Ensemble in generation 1 of Ensembles
# Model Number: 27 with model Ensemble in generation 1 of Ensembles
# Model Number: 28 with model Ensemble in generation 1 of Ensembles
# Model Number: 29 with model Ensemble in generation 1 of Ensembles
# Model Number: 30 with model Ensemble in generation 1 of Ensembles
# Model Number: 31 with model Ensemble in generation 1 of Ensembles
# Model Number: 32 with model Ensemble in generation 1 of Ensembles
# Model Number: 33 with model Ensemble in generation 1 of Ensembles
# Validation Round: 1
# Model Number: 1 of 5 with model AverageValueNaive for Validation 1
# 📈 1 - AverageValueNaive with avg smape 7.22:
# Model Number: 2 of 5 with model Ensemble for Validation 1
# 2 - Ensemble with avg smape 8.88:
# Model Number: 3 of 5 with model Ensemble for Validation 1
# 3 - Ensemble with avg smape 8.88:
# Model Number: 4 of 5 with model AverageValueNaive for Validation 1
# 4 - AverageValueNaive with avg smape 14.51:
# Model Number: 5 of 5 with model Ensemble for Validation 1
# 5 - Ensemble with avg smape 7.47:
# Validation Round: 2
# Model Number: 1 of 5 with model AverageValueNaive for Validation 2
# 📈 1 - AverageValueNaive with avg smape 10.8:
# Model Number: 2 of 5 with model Ensemble for Validation 2
# 2 - Ensemble with avg smape 11.24:
# Model Number: 3 of 5 with model Ensemble for Validation 2
# 3 - Ensemble with avg smape 11.24:
# Model Number: 4 of 5 with model AverageValueNaive for Validation 2
# 4 - AverageValueNaive with avg smape 18.25:
# Model Number: 5 of 5 with model Ensemble for Validation 2
# 📈 5 - Ensemble with avg smape 7.61:
# Model Number: 44 with model Ensemble in generation 2 of Ensembles
# Model Number: 45 with model Ensemble in generation 2 of Ensembles
# Model Number: 46 with model Ensemble in generation 2 of Ensembles
# Model Number: 47 with model Ensemble in generation 2 of Ensembles
# Model Number: 48 with model Ensemble in generation 2 of Ensembles
# Validation Round: 1
# Model Number: 1 of 5 with model Ensemble for Validation 1
# 📈 1 - Ensemble with avg smape 7.36:
# Model Number: 2 of 5 with model Ensemble for Validation 1
# 2 - Ensemble with avg smape 8.88:
# Model Number: 3 of 5 with model Ensemble for Validation 1
# 3 - Ensemble with avg smape 7.36:
# Model Number: 4 of 5 with model Ensemble for Validation 1
# 4 - Ensemble with avg smape 8.88:
# Model Number: 5 of 5 with model Ensemble for Validation 1
# 📈 5 - Ensemble with avg smape 6.78:
# Validation Round: 2
# Model Number: 1 of 5 with model Ensemble for Validation 2
# 📈 1 - Ensemble with avg smape 9.1:
# Model Number: 2 of 5 with model Ensemble for Validation 2
# 2 - Ensemble with avg smape 11.23:
# Model Number: 3 of 5 with model Ensemble for Validation 2
# 3 - Ensemble with avg smape 9.1:
# Model Number: 4 of 5 with model Ensemble for Validation 2
# 4 - Ensemble with avg smape 11.23:
# Model Number: 5 of 5 with model Ensemble for Validation 2
# 📈 5 - Ensemble with avg smape 8.1:
# Initiated AutoTS object with best model:
# Ensemble
# {}
# {'model_name': 'BestN', 'model_count': 2, 'model_metric': 'horizontal', 'models': {'5e75ed52611fa9266c855f5876eb8720': {'Model': 'AverageValueNaive', 'ModelParameters': '{"method": "Mean", "window": null}', 'TransformationParameters': '{"fillna": "fake_date", "transformations": {"0": "DifferencedTransformer", "1": "SinTrend"}, "transformation_params": {"0": {}, "1": {}}}'}, 'de10024adbff2e0ee8be24ef36cdd66d': {'Model': 'Ensemble', 'ModelParameters': '{"model_name": "BestN", "model_count": 5, "model_metric": "mixed_metric", "models": {"5e75ed52611fa9266c855f5876eb8720": {"Model": "AverageValueNaive", "ModelParameters": "{\\"method\\": \\"Mean\\", \\"window\\": null}", "TransformationParameters": "{\\"fillna\\": \\"fake_date\\", \\"transformations\\": {\\"0\\": \\"DifferencedTransformer\\", \\"1\\": \\"SinTrend\\"}, \\"transformation_params\\": {\\"0\\": {}, \\"1\\": {}}}"}, "1402d543604059add51216ad72a0b914": {"Model": "AverageValueNaive", "ModelParameters": "{\\"method\\": \\"Mean\\", \\"window\\": null}", "TransformationParameters": "{\\"fillna\\": \\"rolling_mean\\", \\"transformations\\": {\\"0\\": \\"AlignLastValue\\", \\"1\\": \\"StandardScaler\\", \\"2\\": \\"DifferencedTransformer\\", \\"3\\": \\"bkfilter\\"}, \\"transformation_params\\": {\\"0\\": {\\"rows\\": 1, \\"lag\\": 1, \\"method\\": \\"additive\\", \\"strength\\": 1.0, \\"first_value_only\\": false, \\"threshold\\": null}, \\"1\\": {}, \\"2\\": {\\"lag\\": 7, \\"fill\\": \\"bfill\\"}, \\"3\\": {}}}"}, "cddb0ef2d7d62c155450935ec97757e5": {"Model": "AverageValueNaive", "ModelParameters": "{\\"method\\": \\"Mean\\", \\"window\\": null}", "TransformationParameters": "{\\"fillna\\": \\"mean\\", \\"transformations\\": {\\"0\\": \\"ClipOutliers\\", \\"1\\": \\"QuantileTransformer\\", \\"2\\": \\"DifferencedTransformer\\"}, \\"transformation_params\\": {\\"0\\": {\\"method\\": \\"clip\\", \\"std_threshold\\": 3, \\"fillna\\": null}, \\"1\\": {\\"output_distribution\\": \\"uniform\\", \\"n_quantiles\\": 266}, \\"2\\": {}}}"}, "c6f24b2a048a4e43d3b8e9cb07c74aa6": {"Model": "AverageValueNaive", "ModelParameters": "{\\"method\\": \\"Median\\", \\"window\\": null}", "TransformationParameters": "{\\"fillna\\": \\"rolling_mean\\", \\"transformations\\": {\\"0\\": \\"AlignLastValue\\", \\"1\\": \\"IntermittentOccurrence\\", \\"2\\": \\"AlignLastValue\\", \\"3\\": \\"AlignLastValue\\", \\"4\\": \\"MinMaxScaler\\"}, \\"transformation_params\\": {\\"0\\": {\\"rows\\": 1, \\"lag\\": 1, \\"method\\": \\"additive\\", \\"strength\\": 1.0, \\"first_value_only\\": false, \\"threshold\\": 10}, \\"1\\": {\\"center\\": \\"mean\\"}, \\"2\\": {\\"rows\\": 1, \\"lag\\": 1, \\"method\\": \\"multiplicative\\", \\"strength\\": 1.0, \\"first_value_only\\": false, \\"threshold\\": 1}, \\"3\\": {\\"rows\\": 7, \\"lag\\": 1, \\"method\\": \\"additive\\", \\"strength\\": 1.0, \\"first_value_only\\": false, \\"threshold\\": 10}, \\"4\\": {}}}"}, "d17e2a6ebd15f77f723f411576e84209": {"Model": "ETS", "ModelParameters": "{\\"damped_trend\\": false, \\"trend\\": null, \\"seasonal\\": null, \\"seasonal_periods\\": null}", "TransformationParameters": "{\\"fillna\\": \\"rolling_mean\\", \\"transformations\\": {\\"0\\": \\"AlignLastValue\\", \\"1\\": \\"RobustScaler\\", \\"2\\": \\"LevelShiftTransformer\\"}, \\"transformation_params\\": {\\"0\\": {\\"rows\\": 1, \\"lag\\": 1, \\"method\\": \\"additive\\", \\"strength\\": 1.0, \\"first_value_only\\": false, \\"threshold\\": 1}, \\"1\\": {}, \\"2\\": {\\"window_size\\": 90, \\"alpha\\": 4.0, \\"grouping_forward_limit\\": 3, \\"max_level_shifts\\": 5, \\"alignment\\": \\"rolling_diff\\"}}}"}}, "point_method": "median", "model_weights": {}}', 'TransformationParameters': '{}'}}, 'model_weights': {}, 'point_method': 'mean'}
# Validation: 0, 1, 2
# SMAPE: 4.629911248522804, 6.776060463773164, 8.098334298080704
# MAE: 1.7802635262016926, 3.2278408159698655, 5.255113407030104
# SPL: 0.6142251467992599, 1.7275642319914495, 0.8613129639470768
