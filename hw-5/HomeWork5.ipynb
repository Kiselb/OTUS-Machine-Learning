# %% [markdown]
# Скачайте датасет по ссылке: https://www.kaggle.com/uciml/breast-cancer-wisconsin-data

# %% [markdown]
# #### Загрузка данных

# %% [markdown]
# ### Часть 1. EDA

# %% [markdown]
# #### 1.1. Загрузка данных

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data.csv")
data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# #### 1.2. Параметры датасета

# %%
data['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
data.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data.shape
# Out:
# (569, 33)

# %%
data.empty
# Out:
# False

# %%
data['diagnosis'].value_counts().plot.bar(figsize=(7, 7))
plt.grid(axis='y')

# %% [markdown]
# Наблюдается дисбаланс

# %%
data['diagnosis'].value_counts(normalize=True)
# Out:
# diagnosis
# B    0.627417
# M    0.372583
# Name: proportion, dtype: float64

# %%
data['diagnosis'] = data['diagnosis'].apply(lambda x: 1 if x == 'M' else -1)
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751         -1         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
y = data.loc[:,'diagnosis']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568   -1
# Name: diagnosis, Length: 569, dtype: int64

# %%
x = data.drop('id', axis=1).drop('diagnosis', axis=1).drop('Unnamed: 32', axis=1)
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751         -1         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
features_names = x.columns.tolist()
print(features_names)
# Out:
# ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %% [markdown]
# Приведение значений признаков к одному масштабу при помощи стандартизации. Это делается для нивелирования влияния абсолютных величин при вычислении целевого признака.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
xs = scaler.fit_transform(x.to_numpy())
xs = pd.DataFrame(xs, columns = features_names)
xs.describe()
# Out:
#         radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -1.373633e-16  6.868164e-17   -1.248757e-16 -2.185325e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02         5.690000e+02
# mean     -8.366672e-16      1.873136e-16    4.995028e-17        -4.995028e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00         1.000880e+00
# ...

# %% [markdown]
# #### 1.3. Гистограммы/распределения признаков

# %%
import seaborn as sns

# %%
sns.displot(xs, kind="kde")

# %%
xs.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'radius_mean'}>,
#         <Axes: title={'center': 'texture_mean'}>,
#         <Axes: title={'center': 'perimeter_mean'}>,
#         <Axes: title={'center': 'area_mean'}>,
#         <Axes: title={'center': 'smoothness_mean'}>],
#        [<Axes: title={'center': 'compactness_mean'}>,
#         <Axes: title={'center': 'concavity_mean'}>,
#         <Axes: title={'center': 'concave points_mean'}>,
#         <Axes: title={'center': 'symmetry_mean'}>,
#         <Axes: title={'center': 'fractal_dimension_mean'}>],
#        [<Axes: title={'center': 'radius_se'}>,
#         <Axes: title={'center': 'texture_se'}>,
#         <Axes: title={'center': 'perimeter_se'}>,
#         <Axes: title={'center': 'area_se'}>,
#         <Axes: title={'center': 'smoothness_se'}>],
#        [<Axes: title={'center': 'compactness_se'}>,
#         <Axes: title={'center': 'concavity_se'}>,
#         <Axes: title={'center': 'concave points_se'}>,
# ...

# %% [markdown]
# #### 1.4. HeatMap матрицы корреляций

# %%
plt.figure(figsize=(13, 13))
sns.heatmap(xs.corr(), annot=True, cbar=False, linewidths=0.5, fmt='.2f')
# Out:
# <Axes: >

# %%
data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751         -1         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %% [markdown]
# #### 1.5. Попарные диаграммы рассеяния между признаки с большой корреляцией (>= 0.9 в heatmap)

# %%
sns.pairplot(data, hue='diagnosis', vars=[
    'radius_mean', 'perimeter_mean', 'area_mean', 'radius_worst', 'perimeter_worst', 'area_worst', 
    'texture_mean', 'texture_worst', 
    'concave points_mean', 'concave points_worst',
    'radius_se', 'perimeter_se', 'area_se',
    ], height=1.5
)

# %%
xs
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
# ...

# %% [markdown]
# #### 1.6. BoxPlots

# %%
ax = sns.boxplot(xs)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# C:\Users\MVKiselev\AppData\Local\Temp\ipykernel_20448\3779633661.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# [Text(0, 0, 'radius_mean'),
#  Text(1, 0, 'texture_mean'),
#  Text(2, 0, 'perimeter_mean'),
#  Text(3, 0, 'area_mean'),
#  Text(4, 0, 'smoothness_mean'),
#  Text(5, 0, 'compactness_mean'),
#  Text(6, 0, 'concavity_mean'),
#  Text(7, 0, 'concave points_mean'),
#  Text(8, 0, 'symmetry_mean'),
#  Text(9, 0, 'fractal_dimension_mean'),
#  Text(10, 0, 'radius_se'),
#  Text(11, 0, 'texture_se'),
#  Text(12, 0, 'perimeter_se'),
#  Text(13, 0, 'area_se'),
#  Text(14, 0, 'smoothness_se'),
#  Text(15, 0, 'compactness_se'),
#  Text(16, 0, 'concavity_se'),
#  Text(17, 0, 'concave points_se'),
#  Text(18, 0, 'symmetry_se'),
#  Text(19, 0, 'fractal_dimension_se'),
#  Text(20, 0, 'radius_worst'),
#  Text(21, 0, 'texture_worst'),
# ...

# %% [markdown]
# Предположу, что для решения задачи, наиболее удобными принаками будут те признаки, у которых распределение ближе к нормальному. Примером такого признака является признак texture_mean. К плохим признакам я бы отнёс признак area_se.

# %%
xsy = pd.concat([xs, y], axis=1)
xsy
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
# ...

# %%
xsym=xsy.loc[xsy["diagnosis"] == 1]
xsym
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       1.097064     -2.073335        1.269934   0.984375         1.568466
# 1       1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2       1.579888      0.456187        1.566503   1.558884         0.942210
# 3      -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4       1.750297     -1.151816        1.776573   1.826229         0.280372
# ..           ...           ...             ...        ...              ...
# 563     1.929226      1.349781        2.101976   1.968434         0.963560
# 564     2.110995      0.721473        2.060786   2.343856         1.041842
# 565     1.704854      2.085134        1.615931   1.723842         0.102458
# 566     0.702284      2.045574        0.672676   0.577953        -0.840484
# 567     1.838341      2.336457        1.982524   1.735218         1.525767
#
# ...

# %%
xsyb=xsy.loc[xsy["diagnosis"] == -1]
xsyb
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 19     -0.166799     -1.147162       -0.185728  -0.251957         0.101747
# 20     -0.297446     -0.833008       -0.261106  -0.383638         0.792763
# 21     -1.313080     -1.593959       -1.302806  -1.083572         0.429819
# 37     -0.311646     -0.202373       -0.385500  -0.372831        -0.464730
# 46     -1.684571     -0.570050       -1.658278  -1.288347        -0.737294
# ..           ...           ...             ...        ...              ...
# 558     0.131416      0.788958        0.182100   0.006288        -0.827674
# 559    -0.743348      1.079841       -0.718729  -0.714976        -0.266890
# 560    -0.021952      1.829157       -0.024262  -0.154973         0.208495
# 561    -0.831392      2.345765       -0.877311  -0.764748        -1.556408
# 568    -1.808401      1.221792       -1.814389  -1.347789        -3.112085
#
# ...

# %%
xsym = xsym.drop('diagnosis', axis=1)
xsyb = xsyb.drop('diagnosis', axis=1)

# %%
ax = sns.boxplot(xsym,linecolor='Red')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax = sns.boxplot(xsyb)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# Out:
# C:\Users\MVKiselev\AppData\Local\Temp\ipykernel_20448\3271479881.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# C:\Users\MVKiselev\AppData\Local\Temp\ipykernel_20448\3271479881.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
# [Text(0, 0, 'radius_mean'),
#  Text(1, 0, 'texture_mean'),
#  Text(2, 0, 'perimeter_mean'),
#  Text(3, 0, 'area_mean'),
#  Text(4, 0, 'smoothness_mean'),
#  Text(5, 0, 'compactness_mean'),
#  Text(6, 0, 'concavity_mean'),
#  Text(7, 0, 'concave points_mean'),
#  Text(8, 0, 'symmetry_mean'),
#  Text(9, 0, 'fractal_dimension_mean'),
#  Text(10, 0, 'radius_se'),
#  Text(11, 0, 'texture_se'),
#  Text(12, 0, 'perimeter_se'),
#  Text(13, 0, 'area_se'),
# ...

# %% [markdown]
# На диаграмме хорошо видно как распределены признаки для разных значений целевого значения. Чем больше зазор между боксами, может ошибаюсь, тем лучше признак. Лучше в том смысле, что его значения хорошо разделены относительно значений целевого признака. Т.е. зазор указывает на то, насколько хорошо признак позволяет выполнить предсказание.

# %% [markdown]
# ### Часть 2. Моделирование при помощи kNN

# %% [markdown]
# #### 2.1. Приведение параметров к одному масштабу
#
# Масштабирование параметров произведено в конце пункта 1.2. Переменная **xs**

# %% [markdown]
# #### 2.2. Построение модели kNN "из коробки" без настройки параметров

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def quality(prediction, truth):
    accuracy = accuracy_score(prediction, truth)
    precision = precision_score(prediction, truth)
    recall = recall_score(prediction, truth)
    f1 = f1_score(prediction, truth)
    print("Accuracy:  {:.3f}\nPrecision: {:.5f}\nRecall:    {:.5f}\nF1-score:  {:.5f}".format(
        accuracy, precision, recall, f1
    ))

# %% [markdown]
# Разбиение данных train-test

# %%
X_train, X_test, y_train, y_test = train_test_split(xs, y, test_size=0.7, random_state=13, stratify=y)
y_train
# Out:
# 166   -1
# 359   -1
# 174   -1
# 9      1
# 473   -1
#       ..
# 386   -1
# 494   -1
# 531   -1
# 266   -1
# 273   -1
# Name: diagnosis, Length: 170, dtype: int64

# %% [markdown]
# Обучение модели

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_train)
quality(y_pred, y_train)
# Out:
# Accuracy:  0.976
# Precision: 0.96825
# Recall:    0.96825
# F1-score:  0.96825

# %% [markdown]
# Предсказание по тестовым данным

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_test, y_test)
y_pred = knn.predict(X_test)
quality(y_pred, y_test)
# Out:
# Accuracy:  0.975
# Precision: 0.93960
# Recall:    0.99291
# F1-score:  0.96552

# %% [markdown]
# Следует отметить что, точность упала, а полнота, наоборот, увеличилась. Это обясняется тем, что параметры взаимно исключающие - живут на одной кривой.

# %% [markdown]
# Построение ROC-кривой и определение площади под кривой

# %%
from sklearn import metrics

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, knn.predict_proba(X_test)[:,1])
roc_auc = metrics.auc(tpr, fpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.show()

# %%
tpr
# Out:
# array([0.        , 0.74496644, 0.87248322, 0.93959732, 0.98657718,
#        1.        , 1.        ])

# %%
fpr
# Out:
# array([0.   , 0.   , 0.   , 0.004, 0.028, 0.152, 1.   ])

# %%
area = 0
for i in range(1, len(tpr)):
    area = area + tpr[i] * abs(fpr[i] - fpr[i-1])
area
# Out:
# 0.9994362416107383

# %% [markdown]
# #### 2.3. Настройка модели с помощью кросс-валидации

# %%
from sklearn.model_selection import GridSearchCV

# %%
k = {'n_neighbors':[1, 2, 5, 10, 15, 20, 30, 40, 50, 75, 100]}
knn = KNeighborsClassifier()

# %% [markdown]
# В данном примере важна Полнота (Recall)

# %%
clf = GridSearchCV(knn, k, cv = 20, scoring = 'recall')
clf.fit(xs, y)
print('Best params: ', clf.best_params_)
print('Best recall: ', clf.best_score_)
# Out:
# Best params:  {'n_neighbors': 5}
# Best recall:  0.929090909090909

# %% [markdown]
# Особо лучше не стало. Но это не значит, что не надо использовать данный подход (кросс-валидация), поскольку можно быть уверенным в значениях метрик качества, в отличии от использования метода "из коробки"

# %% [markdown]
# ### Часть 3. Бонусное задание для любопытствующих

# %% [markdown]
# #### 3.1. Фильтрация признаков с корреляцией Пирсона > 0.85

# %%
import numpy as np

# %% [markdown]
# Для фильтрации используется несколько прямолинейный алгоритм. Найти библиотеку для устранения мультиколлинеарности не удалось. Предлагаются трудоёмкие методы, вплоть до построения специфических графов независимости признаков.  Есть радикальный вариант: разложить матрицу ковариаций признаков на собственные числа и векторы. Затем восстановить матрицу признаков используя собственные векторы, соответствующие собственным числам выше некоторого порога (https://habr.com/ru/companies/otus/articles/769274/)

# %%
corr = xs.corr()
columns = np.full((corr.shape[0],), True, dtype=bool)
for i in range(corr.shape[0]):
    for j in range(i + 1, corr.shape[0]):
        if abs(corr.iloc[i,j]) > 0.85:
            if columns[j]:
                columns[j] = False

# %%
columns
# Out:
# array([ True,  True, False, False,  True,  True, False, False,  True,
#         True,  True,  True, False, False,  True,  True,  True,  True,
#         True,  True, False, False, False, False,  True, False, False,
#        False,  True,  True])

# %%
selected_columns = xs.columns[columns]
selected_columns.shape
# Out:
# (17,)

# %%
selected_columns
# Out:
# Index(['radius_mean', 'texture_mean', 'smoothness_mean', 'compactness_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se',
#        'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se',
#        'symmetry_se', 'fractal_dimension_se', 'smoothness_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
xssc = xs[selected_columns]
xssc
# Out:
#      radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0       1.097064     -2.073335         1.568466          3.283515
# 1       1.829821     -0.353632        -0.826962         -0.487072
# 2       1.579888      0.456187         0.942210          1.052926
# 3      -0.768909      0.253732         3.283553          3.402909
# 4       1.750297     -1.151816         0.280372          0.539340
# ..           ...           ...              ...               ...
# 564     2.110995      0.721473         1.041842          0.219060
# 565     1.704854      2.085134         0.102458         -0.017833
# 566     0.702284      2.045574        -0.840484         -0.038680
# 567     1.838341      2.336457         1.525767          3.272144
# 568    -1.808401      1.221792        -3.112085         -1.150752
#
#      symmetry_mean  fractal_dimension_mean  radius_se  texture_se  \
# 0         2.217515                2.255747   2.489734   -0.565265
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(xssc, y, test_size=0.7, random_state=13, stratify=y)

# %% [markdown]
# #### 3.2. Построение логистической модели "из коробки"

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression(penalty=None)
log_reg.fit(X_train, y_train)
print("Train quality")
quality(log_reg.predict(X_train), y_train)
print("Test quality")
quality(log_reg.predict(X_test), y_test)
# Out:
# Train quality
# Accuracy:  1.000
# Precision: 1.00000
# Recall:    1.00000
# F1-score:  1.00000
# Test quality
# Accuracy:  0.932
# Precision: 0.84564
# Recall:    0.96923
# F1-score:  0.90323

# %% [markdown]
# Очень странные результаты - предельные парметры качества - такого не должно быть. Где я ошибся найти не смог. С другой стороны, на тестовых данных получен нормальный результат. Если бы модель была переобучена, то на тестовых данных оценки качества просели бы очень сильно, что не наблюдается. В целом не совсем понятно что получилось.

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, log_reg.predict_proba(X_test)[:,1])
roc_auc = metrics.auc(tpr, fpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.show()

# %%
area = 0
for i in range(1, len(tpr)):
    area = area + tpr[i] * abs(fpr[i] - fpr[i-1])
area
# Out:
# 0.9559194630872483

# %% [markdown]
# Влияние коэффициентов на целевую переменную

# %%
fi = pd.DataFrame({"feature": xssc.columns, "importance": log_reg.coef_[0]})
fi.set_index('feature', inplace=True)
fi.sort_values(['importance'], ascending=False, inplace=True)
fi['importance'].plot.bar();

# %% [markdown]
# #### Регуляризация

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'C': [0.001, 0.01, 0.1, 1]}

log_reg = LogisticRegression(penalty = 'l2')
clf = GridSearchCV(log_reg, parameters, scoring = 'recall', cv = 20)
clf.fit(xssc, y)
# Out:
# GridSearchCV(cv=20, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1]}, scoring='recall')

# %%
print('Best C:', clf.best_params_, '\t Best score: ',clf.best_score_)
# Out:
# Best C: {'C': 1} 	 Best score:  0.9436363636363636

# %% [markdown]
# #### Выводы

# %% [markdown]
# kNN из коробки:                         0.99291
# kNN с кросс-валидацией:                 0.92909
# Линейная регрессия:                     0.96923
# Линейная регрессия с регуляризацией:    0.94363
#
# На мой взгляд, kNN более приемлем для решения данной задачи
